# %%
from pylabel import importer

# %%
path_to_annotations = r"C:\Users\Sathwik\Downloads\ev\annotations\bbox-annotations.json"
path_to_images = r"C:\Users\Sathwik\Downloads\ev\images"

# %%
dataset = importer.ImportCoco(path_to_annotations, path_to_images=path_to_images, name="bbox_coco")

# %%
dataset.df['cat_id'] = dataset.df['cat_id'].map({'1' : '0', '2' : '1'})

# %%
dataset.df.head()
# Out:
#                               img_folder         img_filename img_path  \
# id
# 0   C:\Users\Sathwik\Downloads\ev\images  image_000000001.jpg
# 1   C:\Users\Sathwik\Downloads\ev\images  image_000000001.jpg
# 2   C:\Users\Sathwik\Downloads\ev\images  image_000000001.jpg
# 3   C:\Users\Sathwik\Downloads\ev\images  image_000000001.jpg
# 4   C:\Users\Sathwik\Downloads\ev\images  image_000000002.jpg
#
#     img_id  img_width  img_height img_depth ann_segmented  ann_bbox_xmin  \
# id
# 0        0       1024         768                                    846
# 1        0       1024         768                                    848
# 2        0       1024         768                                     74
# 3        0       1024         768                                    153
# 4        1       1024         576                                    488
#
#     ann_bbox_ymin  ...  ann_segmentation  ann_iscrowd  ann_pose  \
# id                 ...
# ...

# %%
print(f"Number of images: {dataset.analyze.num_images}")
print(f"Number of classes: {dataset.analyze.num_classes}")
print(f"Classes:{dataset.analyze.classes}")
print(f"Class counts:\n{dataset.analyze.class_counts}")
print(f"Path to annotations:\n{dataset.path_to_annotations}")
# Out:
# Number of images: 2239
# Number of classes: 2
# Classes:['person', 'car']
# Class counts:
# person    10800
# car        5972
# Name: cat_name, dtype: int64
# Path to annotations:
# C:\Users\Sathwik\Downloads\ev\annotations

# %%
from IPython.display import Image, display
display(dataset.visualize.ShowBoundingBoxes(100))
display(dataset.visualize.ShowBoundingBoxes("image_000000001.jpg"))
# Out:
# <PIL.Image.Image image mode=RGB size=1024x683 at 0x253B5665E50>
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x253B56F16A0>

# %%
dataset.path_to_annotations = r"C:\Users\Sathwik\Downloads\ev\yolo_annotation"
dataset.export.ExportToYoloV5()[0]
# Out:
# 'training\\dataset.yaml'
